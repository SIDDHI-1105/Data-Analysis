# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDDHI-1105/livibe/blob/main/JOB_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AshishJangra27/datasets
# Out:
# fatal: destination path 'datasets' already exists and is not an empty directory.

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/datasets/Job Postings/jobs.csv.zip')

# %%
df.head()
# Out:
#          job_id                                           job_role    company  \
# 0  7.012301e+10      Branch Banking - Calling For Women Candidates  Hdfc Bank
# 1  6.012391e+10                       Product Owner Senior Manager  Accenture
# 2  6.012391e+10  Employee Relations and Policies Associate Manager  Accenture
# 3  6.012391e+10         Employee Relations and Policies Specialist  Accenture
# 4  6.012301e+10                                  SAP BO Consultant   Mindtree
#
#   experience         salary  \
# 0    1-6 Yrs  Not disclosed
# 1  11-15 Yrs  Not disclosed
# 2    3-7 Yrs  Not disclosed
# 3    3-7 Yrs  Not disclosed
# 4    5-7 Yrs  Not disclosed
#
#                                             location  rating        reviews  \
# 0  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...     4.0  39110 Reviews
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
# 2  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
# ...

# %% [markdown]
# ### 1) DATA EXPLORATION

# %% [markdown]
# #### 1.1)INFO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79147 entries, 0 to 79146
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_id           78667 non-null  float64
#  1   job_role         78667 non-null  object
#  2   company          78666 non-null  object
#  3   experience       77398 non-null  object
#  4   salary           78667 non-null  object
#  5   location         77441 non-null  object
#  6   rating           42948 non-null  float64
#  7   reviews          42948 non-null  object
#  8   resposibilities  78647 non-null  object
#  9   posted_on        78667 non-null  object
#  10  job_link         78667 non-null  object
#  11  company_link     78667 non-null  object
# dtypes: float64(2), object(10)
# memory usage: 7.2+ MB

# %% [markdown]
# #### 1.2) Describing

# %%
df.describe()
# Out:
#              job_id        rating
# count  7.866700e+04  42948.000000
# mean   1.255071e+11      3.940144
# std    1.097464e+11      0.519211
# min    1.012200e+10      1.000000
# 25%    4.012350e+10      3.700000
# 50%    6.012350e+10      4.000000
# 75%    2.610226e+11      4.200000
# max    3.112229e+11      5.000000

# %% [markdown]
# ####1.3)Checking Null Values

# %%
df.isnull().sum()
# Out:
# job_id               480
# job_role             480
# company              481
# experience          1749
# salary               480
# location            1706
# rating             36199
# reviews            36199
# resposibilities      500
# posted_on            480
# job_link             480
# company_link         480
# dtype: int64

# %% [markdown]
# ####1.4)Checking Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(5801)

# %%
df['job_role'].unique()
# Out:
# array(['Branch Banking - Calling For Women Candidates',
#        'Product Owner Senior Manager',
#        'Employee Relations and Policies Associate Manager', ...,
#        'Hiring For International Voice Process | Gurgaon | 35k',
#        'Fresher Engineer', 'Anatomy Trainer - Part Time / Full time'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['job_id', 'job_role', 'company', 'experience', 'salary', 'location',
#        'rating', 'reviews', 'resposibilities', 'posted_on', 'job_link',
#        'company_link'],
#       dtype='object')

# %%
df['job_role'].value_counts()
# Out:
# job_role
# Business Development Executive                                            305
# Solution Architect                                                        278
# Customer Service Associate                                                277
# Sales Executive                                                           275
# .Net Fullstack Developer                                                  258
#                                                                          ...
# Outbound Sales Executive, Telecaller Voice Process                          1
# Account executive (US Payroll)                                              1
# Urgent Vacancy Telesales Executive, Telecaller                              1
# Sr. Group Mgr.- Insurance Ops (Motor Claims- Subrogation- US Mkt) PUNE      1
# Executive - Documentation (Ocean Exports)                                   1
# Name: count, Length: 51050, dtype: int64

# %%
df['company'].nunique()
# Out:
# 15313

# %%
df['company'].value_counts()
# Out:
# company
# Lavya Associates             5131
# Accenture                    4446
# Tech Mahindra                1285
# Varite India Pvt. Ltd.        882
# Hucon                         852
#                              ...
# Dua Solutions                   1
# Sheeba Medical Services         1
# CONNECTING TALENT               1
# Afcons Infotech                 1
# People Connect Placements       1
# Name: count, Length: 15313, dtype: int64

# %%
df['experience'].nunique()
# Out:
# 231

# %%
df['experience'].value_counts().head(10)
# Out:
# experience
# 5-10 Yrs    8041
# 3-8 Yrs     4451
# 1-6 Yrs     3302
# 4-9 Yrs     3186
# 2-7 Yrs     3079
# 0-5 Yrs     2825
# 2-5 Yrs     2778
# 1-3 Yrs     2706
# 2-4 Yrs     2488
# 4-6 Yrs     2435
# Name: count, dtype: int64

# %%
df['salary'].nunique()
# Out:
# 813

# %%
df['salary'].value_counts().head(10)
# Out:
# salary
# Not disclosed               45544
# 6,50,000 - 9,00,000 PA.      3330
# 6,00,000 - 8,00,000 PA.      1114
# 5,00,000 - 10,00,000 PA.     1087
# 2,50,000 - 3,50,000 PA.       599
# 2,00,000 - 3,00,000 PA.       486
# 3,00,000 - 5,00,000 PA.       450
# 3,00,000 - 6,00,000 PA.       424
# 2,00,000 - 4,00,000 PA.       382
# 2,00,000 - 5,00,000 PA.       367
# Name: count, dtype: int64

# %%
df['location'].nunique()
# Out:
# 9038

# %%
df['location'].value_counts().head(10)
# Out:
# location
# Bangalore/Bengaluru       10035
# Hyderabad/Secunderabad     3736
# Pune                       3216
# Chennai                    2953
# Mumbai                     2818
# Gurgaon/Gurugram           2733
# Noida                      1678
# Permanent Remote           1644
# Ahmedabad                  1227
# Kolkata                     923
# Name: count, dtype: int64

# %%
df['resposibilities'].nunique()
# Out:
# 61911

# %%
df['resposibilities'].value_counts().head(10)
# Out:
# resposibilities
# agent,tied,business,agency,dst,channel,direct,team                                                                                                             1800
# tied,agency channel,bfsi,agency,team handling,advisors,training,branch management                                                                              1508
# Team Management,Tied Channel,Alternate Channel,Agency Channel,Life Insurance,Selling Skills,Team Training,team training manager                                 876
# training development,partnership distribution,learning development,training,training manager,learning & development                                             630
# Life Insurance,BFSI,Bancassurance,team handling,Channel Management,bank branches,sales,banking                                                                  317
# ...

# %%
df['resposibilities']
# Out:
# 0           Customer Service,Sales,Relationship Management
# 1        Product management,Market analysis,Change mana...
# 2        Business process,Change management,Team manage...
# 3        Business process,Change management,Team manage...
# 4        SAP BO,PL / SQL,Oracle SQL,SAP Business Object...
#                                ...
# 79142    c#,.net core,javascript,Microservices,Angular,...
# 79143    Informatica Mdm,etl,business intelligence,Agil...
# 79144                              pagination,Power Bi,Dax
# 79145    Bengali,International BPO,BPO,Customer Service...
# 79146    Kafka,sql,spring boot,REST API,java,Lambda,Des...
# Name: resposibilities, Length: 79147, dtype: object

# %%
df['posted_on'].nunique()
# Out:
# 26

# %%
df['posted_on'].unique()
# Out:
# array(['1 Day Ago', '3 Days Ago', '2 Days Ago', 'Walk-in3 Days Ago',
#        '7 Days Ago', '9 Days Ago', '5 Days Ago', '4 Days Ago',
#        '6 Days Ago', '8 Days Ago', 'Today', '10 Days Ago',
#        'Walk-in1 Day Ago', 'Walk-in2 Days Ago', 'Walk-in4 Days Ago',
#        'Walk-in5 Days Ago', 'Just Now', 'Walk-inJust Now',
#        'Walk-in9 Days Ago', 'Walk-in8 Days Ago', 'Walk-in10 Days Ago',
#        'Walk-in6 Days Ago', 'Few Hours Ago', 'Walk-in7 Days Ago',
#        'Walk-inFew Hours Ago', 'Walk-inToday', nan], dtype=object)

# %%
df['posted_on'].value_counts().head(10)
# Out:
# posted_on
# 2 Days Ago     12233
# 1 Day Ago      11691
# 3 Days Ago      9984
# 4 Days Ago      8597
# 6 Days Ago      7801
# 5 Days Ago      7584
# 9 Days Ago      7432
# 8 Days Ago      6165
# 10 Days Ago     4197
# 7 Days Ago      1254
# Name: count, dtype: int64

# %% [markdown]
# ####1.5)Remove Colums

# %%
df.columns
# Out:
# Index(['job_id', 'job_role', 'company', 'experience', 'salary', 'location',
#        'rating', 'reviews', 'resposibilities', 'posted_on', 'job_link',
#        'company_link'],
#       dtype='object')

# %%
del df['posted_on']

# %%
del df['job_link']
del df['company_link']

# %%
df.columns
# Out:
# Index(['job_id', 'job_role', 'company', 'experience', 'salary', 'location',
#        'rating', 'reviews', 'resposibilities'],
#       dtype='object')

# %% [markdown]
# ###2) DATA CLEANING

# %% [markdown]
# ####2.1)Dealing with null values
# * Remove rows with null values except rating & reviews.
# * Dealing with rating & reviews saperatly.

# %%
df.isnull().sum()
# Out:
# job_id               480
# job_role             480
# company              481
# experience          1749
# salary               480
# location            1706
# rating             36199
# reviews            36199
# resposibilities      500
# dtype: int64

# %%
df.drop_duplicates(subset='job_id')
# Out:
#              job_id                                           job_role  \
# 0      7.012301e+10      Branch Banking - Calling For Women Candidates
# 1      6.012391e+10                       Product Owner Senior Manager
# 2      6.012391e+10  Employee Relations and Policies Associate Manager
# 3      6.012391e+10         Employee Relations and Policies Specialist
# 4      6.012301e+10                                  SAP BO Consultant
# ...             ...                                                ...
# 73762  2.012300e+10            Partner Success Executive/Edtech/Punjab
# 73763  2.012300e+10            Partner Success Associate/Edtech/Punjab
# 73764  2.312220e+11  Hiring For International Voice Process | Gurga...
# 73765  1.712200e+11                                   Fresher Engineer
# 73766  7.102201e+10            Anatomy Trainer - Part Time / Full time
#
#                      company experience                   salary  \
# ...

# %%
df.dropna(subset='job_id')
# Out:
#              job_id                                           job_role  \
# 0      7.012301e+10      Branch Banking - Calling For Women Candidates
# 1      6.012391e+10                       Product Owner Senior Manager
# 2      6.012391e+10  Employee Relations and Policies Associate Manager
# 3      6.012391e+10         Employee Relations and Policies Specialist
# 4      6.012301e+10                                  SAP BO Consultant
# ...             ...                                                ...
# 79142  6.012301e+10                           .Net Fullstack Developer
# 79143  1.122201e+10        Senior (BI) Business Intelligence Architect
# 79144  1.512220e+11                                  PowerBI Developer
# 79145  2.712220e+11                         Customer Service Associate
# 79146  2.112220e+11                   Senior Java BED ( PAN India)- KG
#
#                      company experience                     salary  \
# ...

# %%
df.dropna(subset='job_id').isnull().sum()
df = df.dropna(subset = ['job_id','resposibilities','company'])

# %%
df = df.dropna(subset = ['job_id','resposibilities','company'])

# %%
df.isnull().sum()
# Out:
# job_id                 0
# job_role               0
# company                0
# experience          1268
# salary                 0
# location            1226
# rating             35718
# reviews            35718
# resposibilities        0
# dtype: int64

# %%
df['experience']
# Out:
# 0          1-6 Yrs
# 1        11-15 Yrs
# 2          3-7 Yrs
# 3          3-7 Yrs
# 4          5-7 Yrs
#            ...
# 79142      3-8 Yrs
# 79143    10-13 Yrs
# 79144     5-10 Yrs
# 79145      0-2 Yrs
# 79146     8-12 Yrs
# Name: experience, Length: 78646, dtype: object

# %%
df['experience'].value_counts()
# Out:
# experience
# 5-10 Yrs     8039
# 3-8 Yrs      4450
# 1-6 Yrs      3302
# 4-9 Yrs      3186
# 2-7 Yrs      3077
#              ...
# 20-26 Yrs       1
# 22-28 Yrs       1
# 19-24 Yrs       1
# 16-21 Yrs       1
# 20-29 Yrs       1
# Name: count, Length: 231, dtype: int64

# %%
df['experience'] = df['experience'].fillna('5-10 Yrs	')

# %%
df.isnull().sum()
# Out:
# job_id                 0
# job_role               0
# company                0
# experience             0
# salary                 0
# location            1226
# rating             35718
# reviews            35718
# resposibilities        0
# dtype: int64

# %%
df['location'].value_counts()
# Out:
# location
# Bangalore/Bengaluru                                                                                            10027
# Hyderabad/Secunderabad                                                                                          3736
# Pune                                                                                                            3216
# Chennai                                                                                                         2953
# Mumbai                                                                                                          2818
#                                                                                                                ...
# Udaipur, Lucknow, Jammu, Jodhpur                                                                                   1
# Kolkata, Bareilly, Rudrapur, Haldwani, Jamshedpur, Nainital, Pilibhit                                              1
# ...

# %%
df['location'] = df['location'].fillna('Bangalore/Bengaluru	')

# %%
df.isnull().sum()
# Out:
# job_id                 0
# job_role               0
# company                0
# experience             0
# salary                 0
# location               0
# rating             35718
# reviews            35718
# resposibilities        0
# dtype: int64

# %%
df['rating']
# Out:
# 0        4.0
# 1        4.1
# 2        4.1
# 3        4.1
# 4        4.1
#         ...
# 79142    4.0
# 79143    3.7
# 79144    3.8
# 79145    3.7
# 79146    3.7
# Name: rating, Length: 78646, dtype: float64

# %%
df['rating'].value_counts()
# Out:
# rating
# 4.1    7929
# 4.0    5234
# 4.2    4004
# 3.9    3992
# 3.7    3486
# 3.8    3088
# 4.3    1781
# 3.6    1615
# 4.4    1357
# 3.5    1333
# 5.0    1235
# 4.5    1133
# 3.3     825
# 4.8     763
# 3.4     668
# 4.6     598
# 4.7     535
# 3.2     526
# 3.1     449
# 2.8     335
# 3.0     319
# 2.9     259
# 4.9     208
# 2.5     181
# 2.7     165
# 2.6     145
# 1.0     122
# 2.1      99
# 2.3      77
# 2.2      68
# 2.4      67
# 2.0      55
# 1.6      48
# 1.8      43
# 1.7      40
# 1.5      36
# 1.1      29
# 1.9      28
# 1.4      20
# 1.3      20
# 1.2      13
# Name: count, dtype: int64

# %%
df['reviews'].value_counts()
# Out:
# reviews
# 32129 Reviews    2928
# 32151 Reviews    1518
# 2 Reviews        1457
# 21440 Reviews    1286
# 3 Reviews        1071
#                  ...
# 882 Reviews         1
# 430 Reviews         1
# 1305 Reviews        1
# 734 Reviews         1
# 883 Reviews         1
# Name: count, Length: 980, dtype: int64

# %%
df['reviews'].unique()
# Out:
# array(['39110 Reviews', '32129 Reviews', '3759 Reviews', '10263 Reviews',
#        '23786 Reviews', '3843 Reviews', '21440 Reviews', '742 Reviews',
#        '18348 Reviews', '218 Reviews', '3172 Reviews', '6258 Reviews',
#        '1441 Reviews', '33480 Reviews', '50163 Reviews', '19288 Reviews',
#        '1190 Reviews', '28658 Reviews', '1686 Reviews', '981 Reviews',
#        '24041 Reviews', '370 Reviews', '56 Reviews', '4744 Reviews',
#        '601 Reviews', '2060 Reviews', '345 Reviews', '1138 Reviews',
#        '1462 Reviews', '1503 Reviews', '3827 Reviews', '274 Reviews',
#        '802 Reviews', '5169 Reviews', '311 Reviews', '4786 Reviews',
#        '59 Reviews', '2611 Reviews', '321 Reviews', '1232 Reviews',
#        '236 Reviews', '613 Reviews', '986 Reviews', '71 Reviews',
#        '102 Reviews', '4795 Reviews', '3118 Reviews', '18335 Reviews',
#        '1747 Reviews', '2239 Reviews', '136 Reviews', '234 Reviews',
# ...

# %%
df['rating'] = df['rating'].fillna(0.0)

# %%
df['reviews'] = df['reviews'].fillna('0 reviews')

# %%
df.isnull().sum()
# Out:
# job_id             0
# job_role           0
# company            0
# experience         0
# salary             0
# location           0
# rating             0
# reviews            0
# resposibilities    0
# dtype: int64

# %% [markdown]
# ####2.2)Dealing with Duplicates

# %%
df = df.drop_duplicates(subset = 'job_id')

# %%
df
# Out:
#              job_id                                           job_role  \
# 0      7.012301e+10      Branch Banking - Calling For Women Candidates
# 1      6.012391e+10                       Product Owner Senior Manager
# 2      6.012391e+10  Employee Relations and Policies Associate Manager
# 3      6.012391e+10         Employee Relations and Policies Specialist
# 4      6.012301e+10                                  SAP BO Consultant
# ...             ...                                                ...
# 73762  2.012300e+10            Partner Success Executive/Edtech/Punjab
# 73763  2.012300e+10            Partner Success Associate/Edtech/Punjab
# 73764  2.312220e+11  Hiring For International Voice Process | Gurga...
# 73765  1.712200e+11                                   Fresher Engineer
# 73766  7.102201e+10            Anatomy Trainer - Part Time / Full time
#
#                      company experience                   salary  \
# ...

# %%
df['job_id'].astype('int')
# Out:
# 0         70123006070
# 1         60123905908
# 2         60123905898
# 3         60123905897
# 4         60123008332
#              ...
# 73762     20123002989
# 73763     20123002957
# 73764    231222003986
# 73765    171220001449
# 73766     71022008732
# Name: job_id, Length: 72988, dtype: int64

# %%
df['job_id'].astype('int').astype(str)
# Out:
# 0         70123006070
# 1         60123905908
# 2         60123905898
# 3         60123905897
# 4         60123008332
#              ...
# 73762     20123002989
# 73763     20123002957
# 73764    231222003986
# 73765    171220001449
# 73766     71022008732
# Name: job_id, Length: 72988, dtype: object

# %% [markdown]
# ####2.3)Change the datatype of job_id

# %%
df['job_id'] = df['job_id'].astype('int').astype(str)

# %% [markdown]
# ####2.4)Clean Experience Column

# %%
df['experience']
# Out:
# 0          1-6 Yrs
# 1        11-15 Yrs
# 2          3-7 Yrs
# 3          3-7 Yrs
# 4          5-7 Yrs
#            ...
# 73762      1-5 Yrs
# 73763      1-5 Yrs
# 73764      1-4 Yrs
# 73765      0-2 Yrs
# 73766      1-6 Yrs
# Name: experience, Length: 72988, dtype: object

# %%
df['experience'].unique()
# Out:
# array(['1-6 Yrs', '11-15 Yrs', '3-7 Yrs', '5-7 Yrs', '5-10 Yrs',
#        '7-12 Yrs', '2-6 Yrs', '2-4 Yrs', '4-9 Yrs', '3-8 Yrs', '4-6 Yrs',
#        '5-10 Yrs\t', '5-9 Yrs', '10-17 Yrs', '10-13 Yrs', '6-11 Yrs',
#        '2-7 Yrs', '0-2 Yrs', '8-12 Yrs', '3-6 Yrs', '9-14 Yrs', '0-5 Yrs',
#        '4-7 Yrs', '4-8 Yrs', '8-13 Yrs', '7-11 Yrs', '3-4 Yrs',
#        '15-22 Yrs', '2-5 Yrs', '10-18 Yrs', '10-15 Yrs', '0-3 Yrs',
#        '5-12 Yrs', '10-14 Yrs', '3-5 Yrs', '6-8 Yrs', '8-10 Yrs',
#        '12-14 Yrs', '10-20 Yrs', '12-22 Yrs', '9-15 Yrs', '6-9 Yrs',
#        '14-18 Yrs', '9-12 Yrs', '6-10 Yrs', '8-11 Yrs', '17-22 Yrs',
#        '1-5 Yrs', '0-4 Yrs', '5-8 Yrs', '0-0 Yrs', '0-13 Yrs', '1-3 Yrs',
#        '3-10 Yrs', '13-20 Yrs', '12-17 Yrs', '11-16 Yrs', '15-20 Yrs',
#        '1-4 Yrs', '0-1 Yrs', '0-8 Yrs', '2-3 Yrs', '8-9 Yrs', '7-10 Yrs',
#        '4-5 Yrs', '14-20 Yrs', '7-9 Yrs', '10-12 Yrs', '10-16 Yrs',
# ...

# %%
for i in df['experience'][:10]:
    print(i)
# Out:
# 1-6 Yrs
# 11-15 Yrs
# 3-7 Yrs
# 3-7 Yrs
# 5-7 Yrs
# 5-10 Yrs
# 5-10 Yrs
# 7-12 Yrs
# 2-6 Yrs
# 3-7 Yrs

# %%
for i in df['experience'][:10]:
    print(i,type(i))
# Out:
# 1-6 Yrs <class 'str'>
# 11-15 Yrs <class 'str'>
# 3-7 Yrs <class 'str'>
# 3-7 Yrs <class 'str'>
# 5-7 Yrs <class 'str'>
# 5-10 Yrs <class 'str'>
# 5-10 Yrs <class 'str'>
# 7-12 Yrs <class 'str'>
# 2-6 Yrs <class 'str'>
# 3-7 Yrs <class 'str'>

# %%
for i in df['experience'][:10]:
    print(i.replace('Yrs',''))
# Out:
# 1-6
# 11-15
# 3-7
# 3-7
# 5-7
# 5-10
# 5-10
# 7-12
# 2-6
# 3-7

# %%
for i in df['experience'][:10]:
    print(i.replace('Yrs','').split('-')[0])
# Out:
# 1
# 11
# 3
# 3
# 5
# 5
# 5
# 7
# 2
# 3

# %%
for i in df['experience'][:10]:
    print(i.replace('Yrs','').split('-')[0])
# Out:
# 1
# 11
# 3
# 3
# 5
# 5
# 5
# 7
# 2
# 3

# %%
for i in df['experience'][:10]:
    print(i.replace('Yrs','').split('-')[0])
    print(i.replace('Yrs','').split('-')[-1])
# Out:
# 1
# 6
# 11
# 15
# 3
# 7
# 3
# 7
# 5
# 7
# 5
# 10
# 5
# 10
# 7
# 12
# 2
# 6
# 3
# 7

# %%
for i in df['experience'][:10]:
    print(i.replace('Yrs','').split('-')[0].strip(), end='-')
    print(i.replace('Yrs','').split('-')[-1].strip())
# Out:
# 1-6
# 11-15
# 3-7
# 3-7
# 5-7
# 5-10
# 5-10
# 7-12
# 2-6
# 3-7

# %% [markdown]
# #####else you can also do..........

# %%
df['min_experience'] = df['experience'].str.replace('Yrs', '').str.split('-').str[0].str.strip().astype('int')

# %%
df['max_experience'] = df['experience'].str.replace('Yrs', '').str.split('-').str[1].str.strip().astype('int')

# %%
df
# Out:
#              job_id                                           job_role  \
# 0       70123006070      Branch Banking - Calling For Women Candidates
# 1       60123905908                       Product Owner Senior Manager
# 2       60123905898  Employee Relations and Policies Associate Manager
# 3       60123905897         Employee Relations and Policies Specialist
# 4       60123008332                                  SAP BO Consultant
# ...             ...                                                ...
# 73762   20123002989            Partner Success Executive/Edtech/Punjab
# 73763   20123002957            Partner Success Associate/Edtech/Punjab
# 73764  231222003986  Hiring For International Voice Process | Gurga...
# 73765  171220001449                                   Fresher Engineer
# 73766   71022008732            Anatomy Trainer - Part Time / Full time
#
#                      company experience                   salary  \
# ...

# %% [markdown]
# ####2.5)Clean Salary Column

# %% [markdown]
# ####2.6)Clean Location Column

# %%
df['location']
# Out:
# 0        Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...
# 1        Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 2        Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 3        Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 4        Hybrid - Kolkata, Hyderabad/Secunderabad, Pune...
#                                ...
# 73762                      Jalandhar, Chandigarh, Amritsar
# 73763                              Ludhiana, Patiala, Moga
# 73764                          New Delhi, Gurgaon/Gurugram
# 73765    Kota, Udaipur, Banswara, Bhiwadi, Jaipur, Alwa...
# 73766      Hybrid - Pondicherry/Puducherry, Salem, Chennai
# Name: location, Length: 72988, dtype: object

# %%
for i in range(50):
  print(df['location'][i])
# Out:
# Kolkata, Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas), rajasthan
# Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru, delhi ncr
# Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru, delhi ncr
# Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru, delhi ncr
# Hybrid - Kolkata, Hyderabad/Secunderabad, Pune, Chennai, Coimbatore, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)
# Kolkata, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)
# Hybrid - Kolkata, Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)
# Hybrid - Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)
# Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru
# ...

# %%
df['location'].str.replace('(All Areas)','')
# Out:
# 0        Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...
# 1        Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 2        Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 3        Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 4        Hybrid - Kolkata, Hyderabad/Secunderabad, Pune...
#                                ...
# 73762                      Jalandhar, Chandigarh, Amritsar
# 73763                              Ludhiana, Patiala, Moga
# 73764                          New Delhi, Gurgaon/Gurugram
# 73765    Kota, Udaipur, Banswara, Bhiwadi, Jaipur, Alwa...
# 73766      Hybrid - Pondicherry/Puducherry, Salem, Chennai
# Name: location, Length: 72988, dtype: object

# %%
df['location'].str.replace('(All Areas)','').str.split(',')
# Out:
# 0        [Kolkata,  Hyderabad/Secunderabad,  Pune,  Ahm...
# 1        [Kolkata,  Mumbai,  Hyderabad/Secunderabad,  P...
# 2        [Kolkata,  Mumbai,  Hyderabad/Secunderabad,  P...
# 3        [Kolkata,  Mumbai,  Hyderabad/Secunderabad,  P...
# 4        [Hybrid - Kolkata,  Hyderabad/Secunderabad,  P...
#                                ...
# 73762                  [Jalandhar,  Chandigarh,  Amritsar]
# 73763                          [Ludhiana,  Patiala,  Moga]
# 73764                       [New Delhi,  Gurgaon/Gurugram]
# 73765    [Kota,  Udaipur,  Banswara,  Bhiwadi,  Jaipur,...
# 73766    [Hybrid - Pondicherry/Puducherry,  Salem,  Che...
# Name: location, Length: 72988, dtype: object

# %%
df['clean_location'] = df['location'].str.replace('(All Areas)', '').str.replace(',', '-').str.replace('/', '-').str.strip().str.split(' ')

# %%
df['clean_location']
# Out:
# 0        [Kolkata-, Hyderabad-Secunderabad-, Pune-, Ahm...
# 1        [Kolkata-, Mumbai-, Hyderabad-Secunderabad-, P...
# 2        [Kolkata-, Mumbai-, Hyderabad-Secunderabad-, P...
# 3        [Kolkata-, Mumbai-, Hyderabad-Secunderabad-, P...
# 4        [Hybrid, -, Kolkata-, Hyderabad-Secunderabad-,...
#                                ...
# 73762                  [Jalandhar-, Chandigarh-, Amritsar]
# 73763                          [Ludhiana-, Patiala-, Moga]
# 73764                      [New, Delhi-, Gurgaon-Gurugram]
# 73765    [Kota-, Udaipur-, Banswara-, Bhiwadi-, Jaipur-...
# 73766    [Hybrid, -, Pondicherry-Puducherry-, Salem-, C...
# Name: clean_location, Length: 72988, dtype: object

# %% [markdown]
# ### 3.Data Analysis

# %% [markdown]
# ####3.1) No of jobs as per the Experience
